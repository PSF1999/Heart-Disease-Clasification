# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv("train.csv")

# %%
test = pd.read_csv("test.csv")

# %%
train_original = train.copy()
test_original = test.copy()

# %%
train.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
train.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
train.shape
# Out:
# (303, 14)

# %%
train['age'].value_counts().plot.bar()

# %%
train['target'].value_counts().plot.bar()

# %%
plt.show()

# %%
sbn.distplot(train['trestbps']);

# %%
train['cp'].plot.box()

# %%
train['trestbps'].plot.box()

# %%
train['chol'].plot.box()

# %%
train['fbs'].plot.box()

# %%
Gender=pd.crosstab(train['sex'],train['target'])
Gender.div(Gender.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
age=pd.crosstab(train['age'],train['target'])
age.div(age.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
chest_pain=pd.crosstab(train['cp'],train['target'])
chest_pain.div(chest_pain.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
bp=pd.crosstab(train['trestbps'],train['target'])
bp.div(bp.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
chol=pd.crosstab(train['chol'],train['target'])
chol.div(chol.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(50,10))

# %%
fbs=pd.crosstab(train['fbs'],train['target'])
fbs.div(fbs.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
train.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
X = train.drop('target',1)

# %%
y = train.target

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_cv, y_train, y_cv = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred_cv = model.predict(x_cv)

# %%
accuracy_score(y_cv,pred_cv)
# Out:
# 0.8021978021978022
